# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_crypto = pd.read_csv("crypto_data.csv")
df_crypto
# Out:
#      Unnamed: 0        CoinName Algorithm  IsTrading ProofType  \
# 0            42         42 Coin    Scrypt       True   PoW/PoS
# 1           365         365Coin       X11       True   PoW/PoS
# 2           404         404Coin    Scrypt       True   PoW/PoS
# 3           611       SixEleven   SHA-256       True       PoW
# 4           808             808   SHA-256       True   PoW/PoS
# ...         ...             ...       ...        ...       ...
# 1247        XBC     BitcoinPlus    Scrypt       True       PoS
# 1248       DVTC      DivotyCoin    Scrypt      False   PoW/PoS
# 1249       GIOT     Giotto Coin    Scrypt      False   PoW/PoS
# 1250       OPSC  OpenSourceCoin   SHA-256      False   PoW/PoS
# 1251       PUNK       SteamPunk       PoS      False       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# ...

# %%
df_crypto = df_crypto[df_crypto.IsTrading != False]
df_crypto = df_crypto.drop(['IsTrading'], axis=1)
df_crypto
# Out:
#      Unnamed: 0     CoinName    Algorithm ProofType  TotalCoinsMined  \
# 0            42      42 Coin       Scrypt   PoW/PoS     4.199995e+01
# 1           365      365Coin          X11   PoW/PoS              NaN
# 2           404      404Coin       Scrypt   PoW/PoS     1.055185e+09
# 3           611    SixEleven      SHA-256       PoW              NaN
# 4           808          808      SHA-256   PoW/PoS     0.000000e+00
# ...         ...          ...          ...       ...              ...
# 1243       SERO   Super Zero       Ethash       PoW              NaN
# 1244        UOS          UOS      SHA-256      DPoI              NaN
# 1245        BDX       Beldex  CryptoNight       PoW     9.802226e+08
# 1246        ZEN      Horizen     Equihash       PoW     7.296538e+06
# 1247        XBC  BitcoinPlus       Scrypt       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 1         2300000000
# 2          532000000
# 3             611000
# 4                  0
# ...

# %%
df_crypto = df_crypto.dropna()
df_crypto
# Out:
#      Unnamed: 0     CoinName    Algorithm ProofType  TotalCoinsMined  \
# 0            42      42 Coin       Scrypt   PoW/PoS     4.199995e+01
# 2           404      404Coin       Scrypt   PoW/PoS     1.055185e+09
# 4           808          808      SHA-256   PoW/PoS     0.000000e+00
# 5          1337    EliteCoin          X13   PoW/PoS     2.927942e+10
# 7           BTC      Bitcoin      SHA-256       PoW     1.792718e+07
# ...         ...          ...          ...       ...              ...
# 1238       ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09
# 1242        GAP      Gapcoin       Scrypt   PoW/PoS     1.493105e+07
# 1245        BDX       Beldex  CryptoNight       PoW     9.802226e+08
# 1246        ZEN      Horizen     Equihash       PoW     7.296538e+06
# 1247        XBC  BitcoinPlus       Scrypt       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 2          532000000
# 4                  0
# 5       314159265359
# 7           21000000
# ...

# %%
df_crypto = df_crypto[df_crypto.TotalCoinsMined > 0]
df_crypto
# Out:
#      Unnamed: 0     CoinName    Algorithm ProofType  TotalCoinsMined  \
# 0            42      42 Coin       Scrypt   PoW/PoS     4.199995e+01
# 2           404      404Coin       Scrypt   PoW/PoS     1.055185e+09
# 5          1337    EliteCoin          X13   PoW/PoS     2.927942e+10
# 7           BTC      Bitcoin      SHA-256       PoW     1.792718e+07
# 8           ETH     Ethereum       Ethash       PoW     1.076842e+08
# ...         ...          ...          ...       ...              ...
# 1238       ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09
# 1242        GAP      Gapcoin       Scrypt   PoW/PoS     1.493105e+07
# 1245        BDX       Beldex  CryptoNight       PoW     9.802226e+08
# 1246        ZEN      Horizen     Equihash       PoW     7.296538e+06
# 1247        XBC  BitcoinPlus       Scrypt       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 2          532000000
# 5       314159265359
# 7           21000000
# 8                  0
# ...

# %%
df_crypto = df_crypto.drop(['CoinName'], axis=1)
df_crypto
# Out:
#      Unnamed: 0    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0            42       Scrypt   PoW/PoS     4.199995e+01              42
# 2           404       Scrypt   PoW/PoS     1.055185e+09       532000000
# 5          1337          X13   PoW/PoS     2.927942e+10    314159265359
# 7           BTC      SHA-256       PoW     1.792718e+07        21000000
# 8           ETH       Ethash       PoW     1.076842e+08               0
# ...         ...          ...       ...              ...             ...
# 1238       ZEPH      SHA-256      DPoS     2.000000e+09      2000000000
# 1242        GAP       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245        BDX  CryptoNight       PoW     9.802226e+08      1400222610
# 1246        ZEN     Equihash       PoW     7.296538e+06        21000000
# 1247        XBC       Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 5 columns]

# %%
# I am dropping the unnamed: 0 column because I recieved a type econvertion error
#additionally, the column is not being used so I dropped it for that reason
df_crypto_dummy = pd.get_dummies(df_crypto, columns=['Algorithm','ProofType'])
df_crypto_dummy= df_crypto_dummy.drop(['Unnamed: 0'], axis=1)
df_crypto_dummy
# Out:
#       TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# 0        4.199995e+01              42                                 0
# 2        1.055185e+09       532000000                                 0
# 5        2.927942e+10    314159265359                                 0
# 7        1.792718e+07        21000000                                 0
# 8        1.076842e+08               0                                 0
# ...               ...             ...                               ...
# 1238     2.000000e+09      2000000000                                 0
# 1242     1.493105e+07       250000000                                 0
# 1245     9.802226e+08      1400222610                                 0
# 1246     7.296538e+06        21000000                                 0
# 1247     1.283270e+05         1000000                                 0
#
#       Algorithm_536  Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# ...

# %% [markdown]
# The number columns increased significanlty in this step. It seems like, there is a column relating to algorithm and proofType for all unique values of the coin

# %%
from sklearn.preprocessing import StandardScaler
crypto_scaled = pd.DataFrame(StandardScaler().fit_transform(df_crypto_dummy))

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=.90)
crypto_pca = pca.fit_transform(crypto_scaled)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.0279317 , 0.02141802, 0.02051615, 0.02044661, 0.0204466 ,
#        0.0204466 , 0.0204466 , 0.02042554, 0.01870913, 0.01756291,
#        0.01741106, 0.01629007, 0.01596154, 0.01551138, 0.01435005,
#        0.01321122, 0.01236583, 0.01206255, 0.01104295, 0.01071499,
#        0.01049079, 0.01040887, 0.01039089, 0.01037741, 0.01035414,
#        0.01034034, 0.01029605, 0.01028233, 0.01028139, 0.01028139,
#        0.01028138, 0.01027965, 0.01027051, 0.01026331, 0.01026202,
#        0.01025761, 0.01025565, 0.01025068, 0.01024924, 0.01024279,
#        0.01024259, 0.01024259, 0.0102419 , 0.01024018, 0.01023676,
#        0.01023495, 0.01023   , 0.01022442, 0.0102233 , 0.0102233 ,
#        0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 ,
#        0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 ,
#        0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 ,
#        0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 ,
# ...

# %%
from sklearn.manifold import TSNE
tsne = TSNE(learning_rate=35)
tsne_features = tsne.fit_transform(crypto_scaled)

# %%
tsne_features.shape
# Out:
# (532, 2)

# %%
crypto_scaled['x'] = tsne_features[:,0]
crypto_scaled['y'] = tsne_features[:,1]

# %%
plt.scatter(crypto_scaled['x'], crypto_scaled['y'])
plt.show()

# %%
from sklearn.cluster import KMeans
crypto = []
k = list(range(1, 11))

for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(crypto_scaled)
    crypto.append(km.inertia_)

# Define a DataFrame to plot the Elbow Curve using hvPlot
elbow_data = {"k": k, "crypto": crypto}
df_elbow = pd.DataFrame(elbow_data)

plt.plot(df_elbow['k'], df_elbow['crypto'])
plt.xticks(range(1,11))
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()
# Out:
# C:\Users\Lakshmi\anaconda3\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:882: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   f"KMeans is known to have a memory leak on Windows "

# %% [markdown]
# Based on the elbow curve that I derived, it looks like cryptocurrencies can be clustered together. The optimal amount of clusters is 4.
